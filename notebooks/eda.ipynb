# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
spot_price = pd.read_parquet("../data/raw/indicator_600.parquet")

# %%
spot_price["datetime"].min()
# Out:
# Timestamp('2022-12-31 23:00:00+0000', tz='UTC')

# %%
spot_price.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 2976 entries, 2025-01-01 00:00:00+01:00 to 2025-01-31 23:45:00+01:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   2976 non-null   float64
# dtypes: float64(1)
# memory usage: 46.5 KB

# %%
spot_price.describe()
# Out:
#              price
# count  2976.000000
# mean     96.689839
# std      48.503991
# min       0.000000
# 25%      60.080000
# 50%     110.290000
# 75%     131.875000
# max     225.000000

# %%
spot_price.isna().sum()
# Out:
# price    0
# dtype: int64

# %%
spot_price.plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

spot_price.groupby(df.index.hour).mean().plot(
    ax=axes[0]
)

spot_price.groupby(df.index.dayofweek).mean().plot.bar(
    ax=axes[1]
)

spot_price.groupby(df.index.month).mean().plot.bar(
    ax=axes[2]
)

plt.show()
